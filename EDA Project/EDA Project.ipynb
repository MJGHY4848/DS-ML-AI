# %%
import numpy as np
import pandas as pd

# %%
Ipl_data = pd.read_csv("IPL_Dataset.csv")

# %% [markdown]
# # 1)  What is the maximum number of matches played by an individual player in a season? Print the player name along with the number of matched played.

# %%
Ipl_data
# Out:
#      Jersey No             Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1           KL Rahul       14    14        2   670          132*
# 1            2     Shikhar Dhawan       17    17        3   618          106*
# 2            3       David Warner       16    16        2   548           85*
# 3            4       Shreyas Iyer       17    17        2   519           88*
# 4            5       Ishan Kishan       14    13        4   516            99
# ..         ...                ...      ...   ...      ...   ...           ...
# 128        129      Khaleel Ahmed        7     1        0     0            0*
# 129        130     Arshdeep Singh        8     1        0     0            0*
# 130        131        Daniel Sams        3     1        0     0            0*
# 131        132  Shreevats Goswami        2     2        0     0            0*
# 132        133        Trent Boult       15     1        0     0            0*
#
# ...

# %%
Ipl_data["Matches"].max()
# Out:
# 17

# %%
max_matches=Ipl_data[Ipl_data["Matches"]==17][["Player","Matches"]]

# %%
print("Max. matches played by an indiividual player: ")
max_matches
# Out:
# Max. matches played by an indiividual player:
#             Player  Matches
# 1   Shikhar Dhawan       17
# 3     Shreyas Iyer       17
# 19  Marcus Stoinis       17
# 67   Kagiso Rabada       17

# %% [markdown]
# # 2) Top 2 players with maximum Average who have scored atleast 2 half centuries ?

# %%
two_half_centuries = Ipl_data[Ipl_data["50"] >= 2]
two_half_centuries
# Out:
#     Jersey No            Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0           1          KL Rahul       14    14        2   670          132*
# 1           2    Shikhar Dhawan       17    17        3   618          106*
# 2           3      David Warner       16    16        2   548           85*
# 3           4      Shreyas Iyer       17    17        2   519           88*
# 4           5      Ishan Kishan       14    13        4   516            99
# 5           6      Quinton Kock       16    16        2   503           78*
# 6           7  Suryakumar Yadav       16    15        3   480           79*
# 7           8  Devdutt Padikkal       15    15        0   473            74
# 8           9       Virat Kohli       15    15        4   466           90*
# 9          10      ABD Villiers       15    14        4   454           73*
# 10         11     Faf Duplessis       13    13        2   449           87*
# ...

# %%
print("Top 2 players with maximum Average who have scored atleast 2 half centuries are: ")
sort_players = two_half_centuries.sort_values(["Avg"], ascending= False)[["Player","Avg"]].head(2)
sort_players
# Out:
# Top 2 players with maximum Average who have scored atleast 2 half centuries are:
#              Player    Avg
# 36  Wriddhiman Saha  71.33
# 4      Ishan Kishan  57.33

# %% [markdown]
# # 3) Create 2 new columns based on Player name. First column will have first name and second column will have last name. Eg: for the player Shikhar Dhawan, Shikhar will be the first name and Dhawan will be the last name.

# %%
Ipl_data['First Name'] = Ipl_data['Player'].str.split(" ").str[0]
Ipl_data['Last Name'] = Ipl_data['Player'].str.split().str[1:].str.join(' ')

Ipl_data
# Out:
#      Jersey No             Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1           KL Rahul       14    14        2   670          132*
# 1            2     Shikhar Dhawan       17    17        3   618          106*
# 2            3       David Warner       16    16        2   548           85*
# 3            4       Shreyas Iyer       17    17        2   519           88*
# 4            5       Ishan Kishan       14    13        4   516            99
# ..         ...                ...      ...   ...      ...   ...           ...
# 128        129      Khaleel Ahmed        7     1        0     0            0*
# 129        130     Arshdeep Singh        8     1        0     0            0*
# 130        131        Daniel Sams        3     1        0     0            0*
# 131        132  Shreevats Goswami        2     2        0     0            0*
# 132        133        Trent Boult       15     1        0     0            0*
#
# ...

# %% [markdown]
# # 4) Create a new column (Cleaned_Highest_score) based on Highest score variable. Remove the Asterik(*) mark and convert the data type into INT.

# %%
Ipl_data['Cleaned_Highest_score'] = Ipl_data['Highest Score'].str.replace('*', '').astype("int")
Ipl_data
# Out:
#      Jersey No             Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1           KL Rahul       14    14        2   670          132*
# 1            2     Shikhar Dhawan       17    17        3   618          106*
# 2            3       David Warner       16    16        2   548           85*
# 3            4       Shreyas Iyer       17    17        2   519           88*
# 4            5       Ishan Kishan       14    13        4   516            99
# ..         ...                ...      ...   ...      ...   ...           ...
# 128        129      Khaleel Ahmed        7     1        0     0            0*
# 129        130     Arshdeep Singh        8     1        0     0            0*
# 130        131        Daniel Sams        3     1        0     0            0*
# 131        132  Shreevats Goswami        2     2        0     0            0*
# 132        133        Trent Boult       15     1        0     0            0*
#
# ...

# %% [markdown]
# # 5) Print the total number of centuries scored in the entire season.

# %%
total_centuries = Ipl_data["100"].sum()
print(f"The total number of centuries scored in the entire season is {total_centuries}")
# Out:
# The total number of centuries scored in the entire season is 5

# %% [markdown]
# # 6) Print all the player names whose strike rate is less than the average strike rate of all players in entire season. Print the player name, his strike rate and average strike rate.

# %%
Ipl_data["Avg_Strike_Rate"]= Ipl_data["Strike rate"].mean()

# %%
Ipl_data["Strike rate"].mean()
# Out:
# 107.36473684210526

# %%
player_strike_rate = Ipl_data[Ipl_data["Strike rate"]< Ipl_data["Strike rate"].mean() ]
player_strike_rate[["Player", "Strike rate", "Avg_Strike_Rate"]]
# Out:
#                   Player  Strike rate  Avg_Strike_Rate
# 51        Ajinkya Rahane       105.60       107.364737
# 55         Glenn Maxwell       101.88       107.364737
# 58         Vijay Shankar       101.04       107.364737
# 61         Josh Philippe       101.29       107.364737
# 62       Gurkeerat Singh        88.75       107.364737
# 65          Kedar Jadhav        93.93       107.364737
# 70      Yashasvi Jaiswal        90.90       107.364737
# 71         Shreyas Gopal        94.87       107.364737
# 77          Murali Vijay        74.41       107.364737
# 79          Chris Jordan        93.54       107.364737
# 80         Navdeep Saini       100.00       107.364737
# 82     Kamlesh Nagarkoti        70.96       107.364737
# 84         Harshal Patel        87.50       107.364737
# 85         Jimmy Neesham       105.55       107.364737
# 86            Tom Banton        90.00       107.364737
# 89     Prabhsimran Singh       100.00       107.364737
# ...

# %%
Ipl_data.tail(50)
# Out:
#      Jersey No               Player  Matches  Inns  Not Out  Runs  \
# 83          84     Tushar Deshpande        5     2        1    21
# 84          85        Harshal Patel        5     2        0    21
# 85          86        Jimmy Neesham        5     3        1    19
# 86          87           Tom Banton        2     2        0    18
# 87          88       Mohammed Siraj        9     3        2    17
# 88          89           Karun Nair        4     3        1    16
# 89          90    Prabhsimran Singh        2     2        0    15
# 90          91          Isuru Udana       10     4        1    15
# 91          92      James Pattinson       10     2        1    15
# 92          93        Kuldeep Yadav        5     2        1    13
# 93          94          Imran Tahir        3     1        1    13
# 94          95            Moeen Ali        3     3        0    12
# 95          96       Sandeep Sharma       13     5        3    12
# ...

# %% [markdown]
# # 7) Please check the correlation between the features and create a heat map.

# %%
num_col = [i for i in Ipl_data.columns if Ipl_data[i].dtypes != "object"]
num_data = Ipl_data[num_col]
num_data
# Out:
#      Jersey No  Matches  Inns  Not Out  Runs    Avg  Balls faced  Strike rate  \
# 0            1       14    14        2   670  55.83          518       129.34
# 1            2       17    17        3   618  44.14          427       144.73
# 2            3       16    16        2   548  39.14          407       134.64
# 3            4       17    17        2   519  34.60          421       123.27
# 4            5       14    13        4   516  57.33          354       145.76
# ..         ...      ...   ...      ...   ...    ...          ...          ...
# 128        129        7     1        0     0   0.00            2         0.00
# 129        130        8     1        0     0   0.00            3         0.00
# 130        131        3     1        0     0   0.00            2         0.00
# 131        132        2     2        0     0   0.00            4         0.00
# 132        133       15     1        0     0   0.00            1         0.00
#
# ...

# %%
num_data.drop(['Jersey No','Avg_Strike_Rate'],axis=1, inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25792\266643445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data.drop(['Jersey No','Avg_Strike_Rate'],axis=1, inplace = True)

# %%
num_data
# Out:
#      Matches  Inns  Not Out  Runs    Avg  Balls faced  Strike rate  100  50  \
# 0         14    14        2   670  55.83          518       129.34    1   5
# 1         17    17        3   618  44.14          427       144.73    2   4
# 2         16    16        2   548  39.14          407       134.64    0   4
# 3         17    17        2   519  34.60          421       123.27    0   3
# 4         14    13        4   516  57.33          354       145.76    0   4
# ..       ...   ...      ...   ...    ...          ...          ...  ...  ..
# 128        7     1        0     0   0.00            2         0.00    0   0
# 129        8     1        0     0   0.00            3         0.00    0   0
# 130        3     1        0     0   0.00            2         0.00    0   0
# 131        2     2        0     0   0.00            4         0.00    0   0
# 132       15     1        0     0   0.00            1         0.00    0   0
#
#      4s  6s  Cleaned_Highest_score
# ...

# %%
num_data.corr()
# Out:
#                         Matches      Inns   Not Out      Runs       Avg  \
# Matches                1.000000  0.728358  0.555261  0.565237  0.306128
# Inns                   0.728358  1.000000  0.464356  0.895914  0.585148
# Not Out                0.555261  0.464356  1.000000  0.308747  0.429888
# Runs                   0.565237  0.895914  0.308747  1.000000  0.687475
# Avg                    0.306128  0.585148  0.429888  0.687475  1.000000
# Balls faced            0.555102  0.889753  0.271021  0.989948  0.664173
# Strike rate            0.371328  0.581468  0.415060  0.517678  0.591306
# 100                    0.128405  0.224328  0.019726  0.382577  0.233726
# 50                     0.455437  0.755027  0.174184  0.912264  0.638326
# 4s                     0.522628  0.846749  0.204779  0.959576  0.623643
# 6s                     0.523367  0.810922  0.391472  0.861166  0.646224
# Cleaned_Highest_score  0.456171  0.832002  0.235613  0.913250  0.774646
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.heatmap(num_data.corr(),cmap='YlOrBr')
# Out:
# <Axes: >

# %% [markdown]
# # 8) Check the list of players who has an average greater than 50 as well strike rate above 120. Print player name, average and strike rate.

# %%
data1=Ipl_data[Ipl_data["Strike rate"]>120]
data1
# Out:
#      Jersey No           Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1         KL Rahul       14    14        2   670          132*
# 1            2   Shikhar Dhawan       17    17        3   618          106*
# 2            3     David Warner       16    16        2   548           85*
# 3            4     Shreyas Iyer       17    17        2   519           88*
# 4            5     Ishan Kishan       14    13        4   516            99
# ..         ...              ...      ...   ...      ...   ...           ...
# 90          91      Isuru Udana       10     4        1    15           10*
# 93          94      Imran Tahir        3     1        1    13           13*
# 97          98    Mohammad Nabi        1     1        1    11           11*
# 110        111   Jasprit Bumrah       15     1        1     5            5*
# 113        114  Dhawal Kulkarni        1     1        1     3            3*
#
# ...

# %%
data1[data1["Avg"]>50][["Player", "Avg", "Strike rate"]]
# Out:
#              Player     Avg  Strike rate
# 0          KL Rahul   55.83       129.34
# 4      Ishan Kishan   57.33       145.76
# 31   Kieron Pollard   53.60       191.42
# 36  Wriddhiman Saha   71.33       139.86
# 37  Ruturaj Gaikwad   51.00       120.71
# 57     Deepak Hooda  101.00       142.25
# 60       Tom Curran   83.00       133.87

# %% [markdown]
# # 9) Please check the list of players who has an average greater than 40 and balls faced above 100. Print player name, average and balls faced.

# %%
data2 = Ipl_data[Ipl_data["Avg"] > 40][Ipl_data["Balls faced"] > 100]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25792\2150361387.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data2 = Ipl_data[Ipl_data["Avg"] > 40][Ipl_data["Balls faced"] > 100]

# %%
data2[["Player", "Avg", "Balls faced"]]
# Out:
#              Player    Avg  Balls faced
# 0          KL Rahul  55.83          518
# 1    Shikhar Dhawan  44.14          427
# 4      Ishan Kishan  57.33          354
# 8       Virat Kohli  42.36          384
# 9      ABD Villiers  45.40          286
# 10    Faf Duplessis  40.81          319
# 14      Eoin Morgan  41.80          302
# 24  Kane Williamson  45.28          237
# 27      Chris Gayle  41.14          210
# 28       Ben Stokes  40.71          200
# 31   Kieron Pollard  53.60          140
# 32    Rahul Tewatia  42.50          183
# 33  Ravindra Jadeja  46.40          135
# 36  Wriddhiman Saha  71.33          153
# 37  Ruturaj Gaikwad  51.00          169

# %% [markdown]
# # 10) Players who scored atleast one century in this season. Create visualization.

# %%
one_century = Ipl_data[Ipl_data["100"]>=1][["Player", "100"]]
one_century
# Out:
#             Player  100
# 0         KL Rahul    1
# 1   Shikhar Dhawan    2
# 13  Mayank Agarwal    1
# 28      Ben Stokes    1

# %%
one_century= one_century.sort_values(["100"], ascending=False)
plt.figure(figsize=(6, 6))
plt.bar(one_century['Player'], one_century['100'], color='skyblue')
plt.xlabel('Players')
plt.ylabel('Number of Centuries')
plt.title('Players with at least one century in the season')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # 11) Players who scored atleast 4 half centuries in this season.

# %%
four_half_centuries = Ipl_data[Ipl_data["50"]>=4]
four_half_centuries[["Player","50"]]
# Out:
#               Player  50
# 0           KL Rahul   5
# 1     Shikhar Dhawan   4
# 2       David Warner   4
# 4       Ishan Kishan   4
# 5       Quinton Kock   4
# 6   Suryakumar Yadav   4
# 7   Devdutt Padikkal   5
# 9       ABD Villiers   5
# 10     Faf Duplessis   4

# %% [markdown]
# # 12) Check the list of players who hit more than 45 boundaries and more than 10 sixes in this season.

# %%
Ipl_data["Total_Boundaries"] = Ipl_data["4s"]+Ipl_data["6s"]
Ipl_data
# Out:
#      Jersey No             Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1           KL Rahul       14    14        2   670          132*
# 1            2     Shikhar Dhawan       17    17        3   618          106*
# 2            3       David Warner       16    16        2   548           85*
# 3            4       Shreyas Iyer       17    17        2   519           88*
# 4            5       Ishan Kishan       14    13        4   516            99
# ..         ...                ...      ...   ...      ...   ...           ...
# 128        129      Khaleel Ahmed        7     1        0     0            0*
# 129        130     Arshdeep Singh        8     1        0     0            0*
# 130        131        Daniel Sams        3     1        0     0            0*
# 131        132  Shreevats Goswami        2     2        0     0            0*
# 132        133        Trent Boult       15     1        0     0            0*
#
# ...

# %%
data3=Ipl_data[Ipl_data["Total_Boundaries"]>45][Ipl_data["6s"]>10]
data3
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25792\404034953.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data3=Ipl_data[Ipl_data["Total_Boundaries"]>45][Ipl_data["6s"]>10]
#     Jersey No            Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0           1          KL Rahul       14    14        2   670          132*
# 1           2    Shikhar Dhawan       17    17        3   618          106*
# 2           3      David Warner       16    16        2   548           85*
# 3           4      Shreyas Iyer       17    17        2   519           88*
# 4           5      Ishan Kishan       14    13        4   516            99
# 5           6      Quinton Kock       16    16        2   503           78*
# 6           7  Suryakumar Yadav       16    15        3   480           79*
# 9          10      ABD Villiers       15    14        4   454           73*
# 10         11     Faf Duplessis       13    13        2   449           87*
# ...

# %% [markdown]
# # 13) Plot a histogram of number of matches played in a season by players.

# %%
plt.hist(Ipl_data["Matches"],6,histtype='bar',edgecolor='black',color='b') # 5 is no of bins (can be 5,6,7)
plt.xlabel('No. of Matches Played')
plt.ylabel('No. of Players')
plt.show()

# %% [markdown]
# # 14) Plot the histogram of balls faced by players.

# %%
plt.hist(Ipl_data["Balls faced"],6,histtype='bar',edgecolor='black',color='b') # 5 is no of bins (can be 5,6,7)
plt.xlabel('No. of Balls Faced')
plt.ylabel('No. of Players')
plt.show()

# %% [markdown]
# # 15) Top 10 players with most runs in a season.

# %%
top_scorers = Ipl_data.sort_values("Runs", ascending= False)
top_scorers.head(10)[["Player","Runs"]]
# Out:
#              Player  Runs
# 0          KL Rahul   670
# 1    Shikhar Dhawan   618
# 2      David Warner   548
# 3      Shreyas Iyer   519
# 4      Ishan Kishan   516
# 5      Quinton Kock   503
# 6  Suryakumar Yadav   480
# 7  Devdutt Padikkal   473
# 8       Virat Kohli   466
# 9      ABD Villiers   454

# %% [markdown]
# # 16)Print the players who played the match but didn't get the batting.

# %%
not_bat = Ipl_data[Ipl_data["Matches"]!=Ipl_data["Inns"]]
not_bat[["Player"]]
# Out:
#                Player
# 4        Ishan Kishan
# 6    Suryakumar Yadav
# 9        ABD Villiers
# 12      Manish Pandey
# 16      Ambati Rayudu
# ..                ...
# 127  Sheldon Cottrell
# 128     Khaleel Ahmed
# 129    Arshdeep Singh
# 130       Daniel Sams
# 132       Trent Boult
#
# [87 rows x 1 columns]

# %% [markdown]
# # 17) Create a new column to show the percentage of total runs scored in 4s and 6s. Then print the top 5 players with maximum percentage.

# %%
Ipl_data["%_run_by_boundaries"] = (Ipl_data["4s"]*4 + Ipl_data["6s"]*6)/Ipl_data["Runs"]*100
Ipl_data
# Out:
#      Jersey No             Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1           KL Rahul       14    14        2   670          132*
# 1            2     Shikhar Dhawan       17    17        3   618          106*
# 2            3       David Warner       16    16        2   548           85*
# 3            4       Shreyas Iyer       17    17        2   519           88*
# 4            5       Ishan Kishan       14    13        4   516            99
# ..         ...                ...      ...   ...      ...   ...           ...
# 128        129      Khaleel Ahmed        7     1        0     0            0*
# 129        130     Arshdeep Singh        8     1        0     0            0*
# 130        131        Daniel Sams        3     1        0     0            0*
# 131        132  Shreevats Goswami        2     2        0     0            0*
# 132        133        Trent Boult       15     1        0     0            0*
#
# ...

# %%
Ipl_data.nlargest(5, "%_run_by_boundaries")[["Player", "%_run_by_boundaries"]]
# Out:
#             Player  %_run_by_boundaries
# 109     Andrew Tye           100.000000
# 48   Andre Russell            76.923077
# 74    Chris Morris            76.470588
# 29   Hardik Pandya            73.309609
# 47    Sunil Narine            72.727273

# %% [markdown]
# # 18) Print the players with top 5 Not out percentages (Not Out percentage can be calculated as number of Not outs divided by Innings).

# %%
Ipl_data["%not_out"] = Ipl_data["Not Out"]/Ipl_data["Inns"]*100
Ipl_data
# Out:
#      Jersey No             Player  Matches  Inns  Not Out  Runs Highest Score  \
# 0            1           KL Rahul       14    14        2   670          132*
# 1            2     Shikhar Dhawan       17    17        3   618          106*
# 2            3       David Warner       16    16        2   548           85*
# 3            4       Shreyas Iyer       17    17        2   519           88*
# 4            5       Ishan Kishan       14    13        4   516            99
# ..         ...                ...      ...   ...      ...   ...           ...
# 128        129      Khaleel Ahmed        7     1        0     0            0*
# 129        130     Arshdeep Singh        8     1        0     0            0*
# 130        131        Daniel Sams        3     1        0     0            0*
# 131        132  Shreevats Goswami        2     2        0     0            0*
# 132        133        Trent Boult       15     1        0     0            0*
#
# ...

# %%
top_not_out_players = Ipl_data.sort_values(["%not_out","Balls faced"], ascending= False)
top_not_out_players[["Player", "%not_out"]].head(10)
# Out:
#               Player  %not_out
# 62   Gurkeerat Singh     100.0
# 68   Lockie Ferguson     100.0
# 105     Pravin Dubey     100.0
# 93       Imran Tahir     100.0
# 97     Mohammad Nabi     100.0
# 114      T Natarajan     100.0
# 115  Prasidh Krishna     100.0
# 116     Rahul Chahar     100.0
# 110   Jasprit Bumrah     100.0
# 113  Dhawal Kulkarni     100.0

# %% [markdown]
# # 19) Create visualization of top 10 players with highest number of sixes.

# %%
highest_sixes = Ipl_data.sort_values("6s", ascending= False).head(10)
highest_sixes
# Out:
#     Jersey No           Player  Matches  Inns  Not Out  Runs Highest Score  \
# 4           5     Ishan Kishan       14    13        4   516            99
# 15         16     Sanju Samson       14    14        1   375            85
# 29         30    Hardik Pandya       14    13        5   281           60*
# 17         18  Nicholas Pooran       14    14        4   353            77
# 14         15      Eoin Morgan       14    14        4   418           68*
# 9          10     ABD Villiers       15    14        4   454           73*
# 27         28      Chris Gayle        7     7        0   288            99
# 0           1         KL Rahul       14    14        2   670          132*
# 31         32   Kieron Pollard       16    12        7   268           60*
# 5           6     Quinton Kock       16    16        2   503           78*
#
#       Avg  Balls faced  Strike rate  ...  50  4s  6s  First Name Last Name  \
# ...

# %%
col=['b','g','c','m','y']
plt.xlabel('Players')
plt.ylabel('No. of Sixes')
plt.xticks(rotation=45, ha='right')
plt.title('Top Sixers',fontsize=20)
plt.bar(highest_sixes["Player"],highest_sixes["6s"],color=col)
for x,y in zip(highest_sixes["Player"],highest_sixes["6s"]):
    plt.text(x,y,y) 
plt.show()

# %% [markdown]
# # 20) Scatter plot of runs scored by a player v/s balls faced in a season. Then find the relationship between these 2 variables.

# %%
plt.xlabel('Balls Faced')
plt.ylabel('Runs Scored')
plt.scatter(Ipl_data["Balls faced"],Ipl_data["Runs"],color='green',marker='.')
plt.show()

# %% [markdown]
# ### SINCE, RUNS SCORED IS INCREASING WITH NUMBER OF BALLS FACED BY PLAYER. SO IT CAN BE CONCLUDED THAT THEY BOTH ARE VERY STRONGLY POSITIVELY CORRELATED.
