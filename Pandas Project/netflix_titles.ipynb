# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # SOLUTION 1

# %%
df = pd.read_excel("netflix_titles.xls")

# %% [markdown]
# ### a

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### b

# %%
print("No of rows: ",df.shape[0])
print("No of columns: ",df.shape[1])
# Out:
# No of rows:  8780
# No of columns:  11

# %% [markdown]
# ### c

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %% [markdown]
# ### d

# %%
df.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8780   8780                  8780           6150
# unique    8780      2                  8780           4516
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6110                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7956           7952             8770   8780.000000
# unique                7671            745             1765           NaN
# ...

# %% [markdown]
# ### e

# %%
df.nunique()
# Out:
# show_id         8780
# type               2
# title           8780
# director        4516
# cast            7671
# country          745
# date_added      1765
# release_year      74
# rating            14
# duration         220
# listed_in        514
# dtype: int64

# %% [markdown]
# ### f

# %%
(df.isnull().mean()*100).round(2)
# Out:
# show_id          0.00
# type             0.00
# title            0.00
# director        29.95
# cast             9.38
# country          9.43
# date_added       0.11
# release_year     0.00
# rating           0.05
# duration         0.00
# listed_in        0.00
# dtype: float64

# %% [markdown]
# ### g

# %%
df.dropna(subset=["director"])
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8774   s8802    Movie                           Zinzana
# 8775   s8803    Movie                            Zodiac
# 8777   s8805    Movie                        Zombieland
# 8778   s8806    Movie                              Zoom
# 8779   s8807    Movie                            Zubaan
#
#                             director  \
# 0                    Kirsten Johnson
# 2                    Julien Leclercq
# 5                      Mike Flanagan
# 6     Robert Cullen, Jos̩ Luis Ucha
# 7                       Haile Gerima
# ...                              ...
# ...

# %% [markdown]
# ### h

# %%
filtered_data=df[df['country'].fillna('').str.contains("Germany")]
filtered_data
# Out:
#      show_id   type                                title  \
# 7         s8  Movie                              Sankofa
# 12       s13  Movie                         Je Suis Karl
# 129     s130  Movie                   An Unfinished Life
# 142     s143  Movie                      Freedom Writers
# 172     s173  Movie                       School of Rock
# ...      ...    ...                                  ...
# 8590   s8618  Movie                                Trash
# 8634   s8662  Movie                      Unfinished Song
# 8641   s8669  Movie                       V for Vendetta
# 8702   s8730  Movie                   Where the Money Is
# 8718   s8746  Movie  Willy Wonka & the Chocolate Factory
#
#                   director                                               cast  \
# 7             Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 12     Christian Schwochow  Luna Wedler, Jannis Niew̦hner, Milan Peschel,...
# ...

# %% [markdown]
# ### i

# %%
df[['duration_number', 'duration_words']] = df['duration'].str.split(expand=True) # expand=True to split duration and return th split columns as dataframe

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### j

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['Day'] = df['date_added'].dt.day
df['Month'] = df['date_added'].dt.month
df['Year'] = df['date_added'].dt.year
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### k

# %%
df["Year"].value_counts()
# Out:
# Year
# 2019.0    1990
# 2020.0    1874
# 2018.0    1621
# 2021.0    1496
# 2017.0    1159
# 2016.0     415
# 2015.0      73
# 2014.0      23
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
df.groupby(["Year","type"]).size()
# Out:
# Year    type
# 2008.0  Movie         1
#         TV Show       1
# 2009.0  Movie         2
# 2010.0  Movie         1
# 2011.0  Movie        13
# 2012.0  Movie         3
# 2013.0  Movie         6
#         TV Show       4
# 2014.0  Movie        19
#         TV Show       4
# 2015.0  Movie        56
#         TV Show      17
# 2016.0  Movie       250
#         TV Show     165
# 2017.0  Movie       835
#         TV Show     324
# 2018.0  Movie      1234
#         TV Show     387
# 2019.0  Movie      1418
#         TV Show     572
# 2020.0  Movie      1281
#         TV Show     593
# 2021.0  Movie       991
#         TV Show     505
# dtype: int64

# %% [markdown]
# ### l

# %%
df.rename(columns={'title': 'movie_title'}, inplace=True)
df
# Out:
#      show_id     type            movie_title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### m

# %%
df[['Genre1','Genre2','Genre3']] = df['listed_in'].str.split(', ', expand=True)
df
# Out:
#      show_id     type            movie_title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # SOLUTION 2

# %%
df1 = pd.read_excel("student1.xls")
df1
# Out:
#      Student_id  Age  Gender      Grade Employed
# 0             1   19    Male  1st Class      yes
# 1             2   20  Female  2nd Class       no
# 2             3   18    Male  1st Class       no
# 3             4   21  Female  2nd Class       no
# 4             5   19    Male  1st Class       no
# ..          ...  ...     ...        ...      ...
# 227         228   21  Female  1st Class       no
# 228         229   20    Male  2nd Class       no
# 229         230   20    Male  3rd Class      yes
# 230         231   19  Female  1st Class      yes
# 231         232   20    Male  3rd Class      yes
#
# [232 rows x 5 columns]

# %%
df2= pd.read_excel("marks1.xls")
df2
# Out:
#      Student_id  Mark     City
# 0             1    95  Chennai
# 1             2    70    Delhi
# 2             3    98   Mumbai
# 3             4    75     Pune
# 4             5    89    Kochi
# ..          ...   ...      ...
# 224         228    99     Pune
# 225         229    70  Chennai
# 226         230    55    Delhi
# 227         231    97   Mumbai
# 228         232    59     Pune
#
# [229 rows x 3 columns]

# %% [markdown]
# ### a

# %%
df3=pd.merge(df1, df2, on='Student_id', how='outer')
df3
# Out:
#      Student_id  Age  Gender      Grade Employed  Mark     City
# 0             1   19    Male  1st Class      yes  95.0  Chennai
# 1             2   20  Female  2nd Class       no  70.0    Delhi
# 2             3   18    Male  1st Class       no  98.0   Mumbai
# 3             4   21  Female  2nd Class       no  75.0     Pune
# 4             5   19    Male  1st Class       no  89.0    Kochi
# ..          ...  ...     ...        ...      ...   ...      ...
# 227         228   21  Female  1st Class       no  99.0     Pune
# 228         229   20    Male  2nd Class       no  70.0  Chennai
# 229         230   20    Male  3rd Class      yes  55.0    Delhi
# 230         231   19  Female  1st Class      yes  97.0   Mumbai
# 231         232   20    Male  3rd Class      yes  59.0     Pune
#
# [232 rows x 7 columns]

# %% [markdown]
# ### b

# %%
df3.groupby("Gender")["Mark"].max()
# Out:
# Gender
# Female     99.0
# Male      100.0
# Name: Mark, dtype: float64

# %%
df3.groupby("Gender")["Mark"].min()
# Out:
# Gender
# Female    40.0
# Male      40.0
# Name: Mark, dtype: float64

# %% [markdown]
# ### c

# %%
df4=df3[df3["Mark"]> df3["Mark"].mean()]
df4[["Student_id","Mark"]]
# Out:
#      Student_id  Mark
# 0             1  95.0
# 2             3  98.0
# 3             4  75.0
# 4             5  89.0
# 11           12  90.0
# ..          ...   ...
# 221         222  74.0
# 222         223  79.0
# 224         225  72.0
# 227         228  99.0
# 230         231  97.0
#
# [137 rows x 2 columns]

# %% [markdown]
# ### d

# %%
df3[(df3["Gender"]=="Male") & (df3["Employed"]=="yes") ]
# Out:
#      Student_id  Age Gender      Grade Employed  Mark     City
# 0             1   19   Male  1st Class      yes  95.0  Chennai
# 5             6   20   Male  2nd Class      yes  69.0  Gwalior
# 7             8   21   Male  3rd Class      yes  54.0  Chennai
# 12           13   19   Male  1st Class      yes  92.0  Gwalior
# 14           15   19   Male  1st Class      yes  97.0     Pune
# 16           17   20   Male  2nd Class      yes  68.0  Gwalior
# 18           19   21   Male  2nd Class      yes  72.0  Chennai
# 29           30   19   Male  1st Class      yes  81.0  Chennai
# 34           35   20   Male  2nd Class      yes  79.0  Gwalior
# 36           37   21   Male  3rd Class      yes  53.0     Pune
# 41           42   19   Male  1st Class      yes  86.0    Delhi
# 43           44   19   Male  1st Class      yes  95.0     Pune
# 45           46   20   Male  2nd Class      yes  79.0    Delhi
# 47           48   21   Male  2nd Class      yes  67.0     Pune
# ...

# %% [markdown]
# ### e

# %%
def iqLevel(num):
    if num >80:
        return "Intelligent"
    elif ((num>=50) & (num <=80)):
        return "Mediocre"
    else:
        return "Weak"
    
df3["IQ_level"] = df3["Mark"].apply(iqLevel)
df3
# Out:
#      Student_id  Age  Gender      Grade Employed  Mark     City     IQ_level
# 0             1   19    Male  1st Class      yes  95.0  Chennai  Intelligent
# 1             2   20  Female  2nd Class       no  70.0    Delhi     Mediocre
# 2             3   18    Male  1st Class       no  98.0   Mumbai  Intelligent
# 3             4   21  Female  2nd Class       no  75.0     Pune     Mediocre
# 4             5   19    Male  1st Class       no  89.0    Kochi  Intelligent
# ..          ...  ...     ...        ...      ...   ...      ...          ...
# 227         228   21  Female  1st Class       no  99.0     Pune  Intelligent
# 228         229   20    Male  2nd Class       no  70.0  Chennai     Mediocre
# 229         230   20    Male  3rd Class      yes  55.0    Delhi     Mediocre
# 230         231   19  Female  1st Class      yes  97.0   Mumbai  Intelligent
# 231         232   20    Male  3rd Class      yes  59.0     Pune     Mediocre
#
# [232 rows x 8 columns]

# %% [markdown]
# ### f

# %%
df3.groupby(["City", "Gender"]).size()
# Out:
# City     Gender
# Bhopal   Female    13
#          Male      15
# Chennai  Female    15
#          Male      18
# Delhi    Female    12
#          Male      20
# Gwalior  Female    14
#          Male      18
# Kochi    Female    10
#          Male      21
# Mumbai   Female    16
#          Male      16
# Pune     Female    15
#          Male      26
# dtype: int64

# %% [markdown]
# ### g

# %%
df5=df3[df3["Gender"]== "Male"]
df5.nlargest(5, "Mark")
# Out:
#      Student_id  Age Gender      Grade Employed   Mark     City     IQ_level
# 149         150   19   Male  1st Class       no  100.0   Bhopal  Intelligent
# 147         148   18   Male  1st Class       no   99.0    Kochi  Intelligent
# 2             3   18   Male  1st Class       no   98.0   Mumbai  Intelligent
# 60           61   18   Male  1st Class       no   98.0  Gwalior  Intelligent
# 62           63   19   Male  1st Class       no   98.0  Chennai  Intelligent

# %% [markdown]
# ### h

# %%
df3['Gender'] = df3['Gender'].replace({'Male': 'M', 'Female': 'F'})
df3
output_file = r'D:\test.csv' 
df3.to_csv(output_file)

# %% [markdown]
# ### i

# %%
df6=df3[df3.duplicated(subset=['Student_id'])]
if len(df6) > 0:
    print("Duplicate student IDs found:")
    print(df6)
else:
    print("No duplicate student IDs found.")
# Out:
# No duplicate student IDs found.

# %% [markdown]
# ### j

# %%
df3.select_dtypes(include=['int', 'float'])
# Out:
#      Student_id  Age  Mark
# 0             1   19  95.0
# 1             2   20  70.0
# 2             3   18  98.0
# 3             4   21  75.0
# 4             5   19  89.0
# ..          ...  ...   ...
# 227         228   21  99.0
# 228         229   20  70.0
# 229         230   20  55.0
# 230         231   19  97.0
# 231         232   20  59.0
#
# [232 rows x 3 columns]

# %% [markdown]
# ### k

# %%
df7=pd.merge(df1, df2, on='Student_id', how='left' , indicator=True)
df7 = df7[df7["_merge"]=="left_only"]
df7.drop("_merge", axis=1,inplace=True)
df7
# Out:
#     Student_id  Age  Gender      Grade Employed  Mark City
# 8            9   22  Female  3rd Class      yes   NaN  NaN
# 9           10   21    Male  1st Class       no   NaN  NaN
# 48          49   19    Male  2nd Class       no   NaN  NaN

# %% [markdown]
# # SOLUTION3

# %% [markdown]
# #### The concept of missing values refers to non availability of data for certain columns or observations we are obtaining data for. this may occur for various reasons like data was not collected or error occured during data entry or some other reaons as well.
#
# #### We can use following methods to identify missing values in a dataframe, such as:
# #### i) isna() and isnull(): These methods return a DataFrame where each cell is True if the corresponding element is NaN or None, and False otherwise.
# #### ii) notna() and notnull(): These are the methods that return True for non-missing values and False for missing values.
#
# #### Different Ways of Treating/Imputing/Deleting Missing Values:
#
# #### Imputaion means to fill missing values with estimated values based on the remaining data of the same column. it involves mean, median, mode or forward filling, backward filling and some othr methods as well
# #### Example of Imputation:

# %%
import pandas as pd
import numpy as np

data = {
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, np.nan, 8],
    'C': [np.nan, 10, 11, 12]
}

df = pd.DataFrame(data)
df
# Out:
#      A    B     C
# 0  1.0  5.0   NaN
# 1  2.0  NaN  10.0
# 2  NaN  NaN  11.0
# 3  4.0  8.0  12.0

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False   True
# 1  False   True  False
# 2   True   True  False
# 3  False  False  False

# %%
df.fillna(df.mean())
# Out:
#           A    B     C
# 0  1.000000  5.0  11.0
# 1  2.000000  6.5  10.0
# 2  2.333333  6.5  11.0
# 3  4.000000  8.0  12.0

# %% [markdown]
# #### Deleting missing values means to delete the rows which contains NaN values, it can be both ,either row deletion or column deletion

# %%
df.dropna(axis=0, inplace=True)
df
# Out:
#      A    B     C
# 3  4.0  8.0  12.0
